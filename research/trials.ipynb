# %% [markdown]
# ### Download data from gdrive

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1JVR3sney8A5-R_eSHbgeQbqSCKcmZnR3/view?usp=sharing"

# %%
type(url)
# Out:
# str

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1JVR3sney8A5-R_eSHbgeQbqSCKcmZnR3'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "CHEST-CT-SCAN-DATASETSET.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1JVR3sney8A5-R_eSHbgeQbqSCKcmZnR3
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1JVR3sney8A5-R_eSHbgeQbqSCKcmZnR3&confirm=t&uuid=3dcab9f9-63f6-4b2c-93aa-938284c43cd9
# To: c:\Users\dimpa\Downloads\PROJECT - HEALTHCARE\chest-cancer-classification-using-mlflow-dvc\research\CHEST-CT-SCAN-DATASET.zip
# 100%|██████████| 49.0M/49.0M [00:05<00:00, 8.81MB/s]
# 'CHEST-CT-SCAN-DATASET.zip'
